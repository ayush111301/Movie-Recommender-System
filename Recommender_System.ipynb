# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush111301/Movie-Recommender-System/blob/main/Recommender_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Movie Recommender System Working**
#
#
#
#
# **Importing Required Libraries and Functions:**

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# **Loading of Data-set**

# %%
movies_frame=pd.read_csv('/content/tmdb_5000_movies.csv')

# %%
movies_frame.shape
# Out:
# (4803, 20)

# %%
movies_frame.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_frame
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_frame.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# **Feature Selection and Preprocessing:**

# %%
relevant_features=['genres','keywords','popularity','title','runtime','tagline']

# %%
for feature in relevant_features:
  movies_frame[feature]=movies_frame[feature].fillna('')

# %%
high_end_features= movies_frame['genres']+ ' ' +movies_frame['keywords']+ ' ' +str(movies_frame['popularity'])+ ' ' +movies_frame['title']+ ' ' +str(movies_frame['runtime'])+ ' ' +movies_frame['tagline']

# %%
print(high_end_features)
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4798    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801    [] [] 0       150.437577\n1       139.082615\n...
# 4802    [{"id": 99, "name": "Documentary"}] [{"id": 15...
# Length: 4803, dtype: object

# %% [markdown]
# **Converting Text into Numbers Using TfidfVectorizer**

# %%
number_vector=TfidfVectorizer()

# %%
relevant_vectors=number_vector.fit_transform(high_end_features)

# %%
print(relevant_vectors)
# Out:
#   (0, 17079)	0.12402699276009423
#   (0, 16853)	0.03608037026269711
#   (0, 21081)	0.05861509482233365
#   (0, 19925)	0.026599056967071426
#   (0, 13212)	0.11022615640925629
#   (0, 16820)	0.01576393966111332
#   (0, 18388)	0.01576393966111332
#   (0, 9679)	0.01576393966111332
#   (0, 9891)	0.01576393966111332
#   (0, 665)	0.01576393966111332
#   (0, 9563)	0.01576393966111332
#   (0, 9500)	0.01576393966111332
#   (0, 894)	0.01576393966111332
#   (0, 2702)	0.01576393966111332
#   (0, 1122)	0.01576393966111332
#   (0, 3152)	0.01576393966111332
#   (0, 2399)	0.01576393966111332
#   (0, 10581)	0.13207961707049187
#   (0, 13714)	0.01576393966111332
#   (0, 12976)	0.03152787932222664
#   (0, 8410)	0.03152787932222664
#   (0, 15616)	0.03152787932222664
#   (0, 17515)	0.01576393966111332
#   (0, 9734)	0.01576393966111332
#   (0, 8409)	0.03152787932222664
#   :	:
#   (4802, 15616)	0.07513270962239035
#   (4802, 17515)	0.03756635481119518
#   (4802, 9734)	0.03756635481119518
# ...

# %% [markdown]
# **Cosine Similarity Use:**

# %%
similarity_score=cosine_similarity(relevant_vectors)

# %%
print(similarity_score)
# Out:
# [[1.         0.34717872 0.29660257 ... 0.28428378 0.0875825  0.22406266]
#  [0.34717872 1.         0.28150239 ... 0.27768253 0.08973024 0.20689568]
#  [0.29660257 0.28150239 1.         ... 0.23768891 0.11522013 0.20831589]
#  ...
#  [0.28428378 0.27768253 0.23768891 ... 1.         0.11203342 0.24060115]
#  [0.0875825  0.08973024 0.11522013 ... 0.11203342 1.         0.13557492]
#  [0.22406266 0.20689568 0.20831589 ... 0.24060115 0.13557492 1.        ]]

# %%
print(similarity_score.shape)
# Out:
# (4803, 4803)

# %% [markdown]
# **Getting User Input:**

# %%
user_movie_input=input("Enter your most liked movie name: ")
# Out:
# Enter your most liked movie name: Super mano

# %%
movies_title_list=movies_frame['title'].tolist()

# %%
print(movies_title_list)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
closest_match=difflib.get_close_matches(user_movie_input, movies_title_list)

# %%
print(closest_match)
# Out:
# ['Superman', 'Superman II', 'Supernova']

# %% [markdown]
# **Making a Column Named index for the Dataframe:**

# %%
for data in movies_frame.columns:
  print(data)
# Out:
# budget
# genres
# homepage
# id
# keywords
# original_language
# original_title
# overview
# popularity
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# vote_average
# vote_count

# %%
movies_frame.insert(0,'index',range(0,len(movies_frame)))

# %%
movies_frame.set_index("index")
# Out:
#           budget                                             genres  \
# index
# 0      237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1      300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2      245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3      250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4      260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...          ...                                                ...
# 4798      220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799        9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800           0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801           0                                                 []
# 4802           0                [{"id": 99, "name": "Documentary"}]
#
#                                                 homepage      id  \
# index
# 0                            http://www.avatarmovie.com/   19995
# ...

# %%
for data in movies_frame.columns:
  print(data)
# Out:
# index
# budget
# genres
# homepage
# id
# keywords
# original_language
# original_title
# overview
# popularity
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# vote_average
# vote_count

# %% [markdown]
# **Getting Index of Movie Entered by User:**

# %%
movie_index=movies_frame[movies_frame.title == closest_match[0]]['index'].values[0]

# %%
print(movie_index)
# Out:
# 813

# %% [markdown]
# **Making a List of all Similarity Scores:**

# %%
similarity = list(enumerate(similarity_score[movie_index]))
print(similarity)
# Out:
# [(0, 0.36862923036110007), (1, 0.3606475308845217), (2, 0.30637986512737864), (3, 0.43029912306655876), (4, 0.3781003049746209), (5, 0.37437340605826064), (6, 0.29740270431186794), (7, 0.39276336219083147), (8, 0.2849739614581479), (9, 0.456876428359834), (10, 0.6696987106635179), (11, 0.26654244901595675), (12, 0.34124974024226407), (13, 0.2658006201820279), (14, 0.6037976175586371), (15, 0.3122476385936356), (16, 0.4165467534611122), (17, 0.35362948510464853), (18, 0.27446065887474075), (19, 0.27333305888300263), (20, 0.34940537899648705), (21, 0.22071447426777685), (22, 0.2233381867418212), (23, 0.25445946261233016), (24, 0.3024131079737503), (25, 0.31581394037386357), (26, 0.41276003623111035), (27, 0.34135060507952036), (28, 0.332526637841896), (29, 0.29797730824404417), (30, 0.38583783178073094), (31, 0.38310496111763576), (32, 0.2792032680979415), (33, 0.42176276295245607), (34, 0.2699945287910405), (35, 0.312223957501401), (36, 0.2557563105161489), (37, 0.2845073520984465), (
# ...

# %% [markdown]
# **Getting Movies which are similar to the movie user entered.**

# %%
sort_movies_similarity=sorted(similarity, key= lambda x:x[1], reverse=True)
print(sort_movies_similarity)
# Out:
# [(813, 0.9999999999999998), (10, 0.6696987106635179), (14, 0.6037976175586371), (870, 0.5963040203577845), (1296, 0.5875380143720114), (65, 0.49818506196220924), (2433, 0.4865776179118866), (119, 0.4793179890983652), (210, 0.46221728109128707), (9, 0.456876428359834), (511, 0.4538780741080254), (428, 0.44033425988130537), (101, 0.43824847644900977), (215, 0.4361086807620209), (232, 0.43592719434810345), (2442, 0.4354477466842701), (299, 0.4351887955523079), (415, 0.4340247426397559), (1359, 0.4313670082793672), (3, 0.43029912306655876), (165, 0.4301002809762358), (1358, 0.4282724413023861), (41, 0.4280930103402443), (1740, 0.4262859509682707), (1382, 0.42588901446596816), (182, 0.4245275202979772), (2428, 0.42398064522424433), (64, 0.4221337428018883), (33, 0.42176276295245607), (539, 0.42121231158181766), (1133, 0.41845673380788595), (122, 0.41836339598087713), (123, 0.41816424438775274), (2217, 0.41661449333819267), (16, 0.4165467534611122), (125, 0.41618413258092335), (4033, 0.414
# ...

# %% [markdown]
# **Printing Names of the Movies having high similarity score based on the user input.**

# %%
print("Recommended Movies: ")
i=1
for movie in sort_movies_similarity:
  index=movie[0]
  index_title=movies_frame[movies_frame.index==index]['title'].values[0]
  if i<=15:
    print(i,'.',index_title)
    i=i+1
# Out:
# Recommended Movies:
# 1 . Superman
# 2 . Superman Returns
# 3 . Man of Steel
# 4 . Superman II
# 5 . Superman III
# 6 . The Dark Knight
# 7 . Superman IV: The Quest for Peace
# 8 . Batman Begins
# 9 . Batman & Robin
# 10 . Batman v Superman: Dawn of Justice
# 11 . X-Men
# 12 . Batman Returns
# 13 . X-Men: First Class
# 14 . Fantastic 4: Rise of the Silver Surfer
# 15 . The Wolverine

# %% [markdown]
# **Movie Recommender Sytem:**

# %%
user_movie_input=input("Enter your most liked movie name: ")

movies_title_list=movies_frame['title'].tolist()

closest_match=difflib.get_close_matches(user_movie_input, movies_title_list)

movie_index=movies_frame[movies_frame.title == closest_match[0]]['index'].values[0]

similarity = list(enumerate(similarity_score[movie_index]))

sort_movies_similarity=sorted(similarity, key= lambda x:x[1], reverse=True)

print("Recommended Movies: ")
i=1
for movie in sort_movies_similarity:
  index=movie[0]
  index_title=movies_frame[movies_frame.index==index]['title'].values[0]
  if i<=20:
    print(i,'.',index_title)
    i=i+1
# Out:
# Enter your most liked movie name: Interstellar
# Recommended Movies:
# 1 . Interstellar
# 2 . Armageddon
# 3 . The Astronaut Farmer
# 4 . Southland Tales
# 5 . Brooklyn's Finest
# 6 . Frequency
# 7 . Austin Powers: The Spy Who Shagged Me
# 8 . The Martian
# 9 . Terminator Genisys
# 10 . Everyone Says I Love You
# 11 . The Fifth Element
# 12 . The Matrix Revolutions
# 13 . Avatar
# 14 . Apollo 13
# 15 . The Matrix Reloaded
# 16 . Nancy Drew
# 17 . 2001: A Space Odyssey
# 18 . Crossroads
# 19 . Event Horizon
# 20 . Dear Frankie
